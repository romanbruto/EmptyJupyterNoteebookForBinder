# %%
d = dict()
d.update({1: 10, 'abc' : 'def', 0 : [0, 1, 2], (0,1) : 'a'})
d[1] += 5
d['abc'] +='def'
d[0].append(3)
d[0].remove(0)
del d[(0,1)]
print(d)
# Out:
# {1: 15, 'abc': 'defdef', 0: [1, 2, 3]}
