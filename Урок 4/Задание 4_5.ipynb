# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(range(-200,200))
y = 1/x

ax = plt.gca()

plt.plot(x, y)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.title('hyperbola')
plt.grid(True)
plt.xlim(-10,10)
plt.show()
# Out:
# <ipython-input-142-31e9637e1762>:5: RuntimeWarning: divide by zero encountered in true_divide
#   y = 1/x
