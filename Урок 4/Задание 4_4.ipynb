# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('winequality-white.csv',';')
df['pH'].hist()
plt.title('pH')
plt.show()
df['density'].hist()
plt.title('density')
plt.show()
